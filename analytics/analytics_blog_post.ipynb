# %%
from labml import analytics

logs = analytics.runs('0e6b2ffc91a011eaacd025586e2d05a3')

dir(logs)
# Out:
# ['model_conv1_bias',
#  'model_conv1_bias_grad',
#  'model_conv1_weight',
#  'model_conv1_weight_grad',
#  'model_conv2_bias',
#  'model_conv2_bias_grad',
#  'model_conv2_weight',
#  'model_conv2_weight_grad',
#  'model_fc1_bias',
#  'model_fc1_bias_grad',
#  'model_fc1_weight',
#  'model_fc1_weight_grad',
#  'model_fc2_bias',
#  'model_fc2_bias_grad',
#  'model_fc2_weight',
#  'model_fc2_weight_grad',
#  'train_loss',
#  'valid_accuracy',
#  'valid_loss']

# %%
analytics.render_altair(logs.train_loss)
# Out:
# sqlite
# train.loss.mean IndicatorClass.queue
# alt.VConcatChart(...)
